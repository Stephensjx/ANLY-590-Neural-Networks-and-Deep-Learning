# %% [markdown]
# # ANLY-590 Assignment 1
# ### Jiaxuan Sun - js4669

# %% [markdown]
# ## Problem 1
# <b>Regularization.</b> Using the accompanying Hitters dataset, we will explore regression models to predict a player’s Salary from other variables. You must python.
# https://gist.github.com/keeganhines/59974f1ebef97bbaa44fb19143f90bad

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso, LassoCV, Ridge, RidgeCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# read raw data
hitters = pd.read_csv('Hitters.csv', sep = ',')
# first look of the data
hitters.head(10)
# Out:
#           Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     -Andy Allanson    293    66      1    30   29     14      1     293
# 1        -Alan Ashby    315    81      7    24   38     39     14    3449
# 2       -Alvin Davis    479   130     18    66   72     76      3    1624
# 3      -Andre Dawson    496   141     20    65   78     37     11    5628
# 4  -Andres Galarraga    321    87     10    39   42     30      2     396
# 5   -Alfredo Griffin    594   169      4    74   51     35     11    4408
# 6         -Al Newman    185    37      1    23    8     21      2     214
# 7   -Argenis Salazar    298    73      0    24   24      7      3     509
# 8     -Andres Thomas    323    81      6    26   32      8      2     341
# 9    -Andre Thornton    401    92     17    49   66     65     13    5206
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# 0     66  ...     30    29      14       A        E     446       33      20
# 1    835  ...    321   414     375       N        W     632       43      10
# 2    457  ...    224   266     263       A        W     880       82      14
# 3   1575  ...    828   838     354       N        E     200       11       3
# 4    101  ...     48    46      33       N        E     805       40       4
# 5   1133  ...    501   336     194       A        W     282      421      25
# 6     42  ...     30     9      24       N        E      76      127       7
# 7    108  ...     41    37      12       A        W     121      283       9
# 8     86  ...     32    34       8       N        W     143      290      19
# 9   1332  ...    784   890     866       A        E       0        0       0
#
#    Salary  NewLeague
# 0     NaN          A
# 1   475.0          N
# 2   480.0          A
# 3   500.0          N
# 4    91.5          N
# 5   750.0          A
# 6    70.0          A
# 7   100.0          A
# 8    75.0          N
# 9  1100.0          A
#
# [10 rows x 21 columns]

# %% [markdown]
# #### Preprocessing the data

# %%
hitters.isna().sum()
# Out:
# Unnamed: 0     0
# AtBat          0
# Hits           0
# HmRun          0
# Runs           0
# RBI            0
# Walks          0
# Years          0
# CAtBat         0
# CHits          0
# CHmRun         0
# CRuns          0
# CRBI           0
# CWalks         0
# League         0
# Division       0
# PutOuts        0
# Assists        0
# Errors         0
# Salary        59
# NewLeague      0
# dtype: int64

# %% [markdown]
# <b>`Salary` column has some missing values need to be droped</b>

# %%
# drop NaN
hitters_new = hitters.dropna()

# %% [markdown]
# ### 1.1
# Use `LASSO` regression to predict Salary from the other `numeric` predictors. Create a visualization of the coefficient trajectories. Comment on which are the final three predictors that remain in the model. Use cross-validation to find the optimal value of the regularization penality. How many predictors are left in that model?

# %%
# drop categorical variables and target varible salary
hitters_df = hitters_new.drop(['Unnamed: 0','League','Division','NewLeague','Salary'],axis = 1)
x = hitters_df.astype('float64')
x.head(5)
# Out:
#    AtBat   Hits  HmRun  Runs   RBI  Walks  Years  CAtBat   CHits  CHmRun  \
# 1  315.0   81.0    7.0  24.0  38.0   39.0   14.0  3449.0   835.0    69.0
# 2  479.0  130.0   18.0  66.0  72.0   76.0    3.0  1624.0   457.0    63.0
# 3  496.0  141.0   20.0  65.0  78.0   37.0   11.0  5628.0  1575.0   225.0
# 4  321.0   87.0   10.0  39.0  42.0   30.0    2.0   396.0   101.0    12.0
# 5  594.0  169.0    4.0  74.0  51.0   35.0   11.0  4408.0  1133.0    19.0
#
#    CRuns   CRBI  CWalks  PutOuts  Assists  Errors
# 1  321.0  414.0   375.0    632.0     43.0    10.0
# 2  224.0  266.0   263.0    880.0     82.0    14.0
# 3  828.0  838.0   354.0    200.0     11.0     3.0
# 4   48.0   46.0    33.0    805.0     40.0     4.0
# 5  501.0  336.0   194.0    282.0    421.0    25.0

# %%
y = hitters_new['Salary']

# %%
alphas = np.linspace(0,20,500)
lasso = Lasso(max_iter = 1e4, normalize = True)
coefs = []

for a in alphas:
    lasso.set_params(alpha = a)
    lasso.fit(x,y)
    coefs.append(lasso.coef_)
    
sns.set(style="darkgrid")
plt.figure(num=None, figsize=(16, 9), dpi=80, facecolor='w', edgecolor='k')    
ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.legend(x.columns,loc = 4)
plt.xlabel('lambda')
plt.ylabel('coefficient')
plt.title('Lasso coefficient trajectories')
plt.show()

# %%
lasso = Lasso(max_iter = 1e4, normalize = True)
lasso.set_params(alpha = 10)
lasso.fit(x,y)
for col, coef in zip(x, lasso.coef_):
    print(col+':', coef)
# Out:
# AtBat: 0.0
# Hits: 0.32947458556868225
# HmRun: 0.0
# Runs: 0.0
# RBI: 0.0
# Walks: 0.0
# Years: 0.0
# CAtBat: 0.0
# CHits: 0.0
# CHmRun: 0.0
# CRuns: 0.07632196852894164
# CRBI: 0.20447491636853793
# CWalks: 0.0
# PutOuts: 0.0
# Assists: 0.0
# Errors: 0.0

# %% [markdown]
# From above result we can find that the final three predictors that remain in the model are `Hits`, `CRuns` and `CRBI`.

# %% [markdown]
# ### Select the optimal regularization penalty using cross validation.

# %%
lassocv = LassoCV(alphas = None, cv = 10, max_iter = 1e5, normalize = True)
lassocv.fit(x,y)
lasso.set_params(alpha = lassocv.alpha_)
lassocv.alpha_
# Out:
# 0.0635481759985745

# %%
lasso.fit(x,y)
pd.Series(lasso.coef_, index=x.columns)
# Out:
# AtBat     -2.082954
# Hits       7.041011
# HmRun      0.000000
# Runs      -0.682615
# RBI        0.496552
# Walks      5.511781
# Years     -6.107625
# CAtBat    -0.087066
# CHits      0.000000
# CHmRun     0.156468
# CRuns      1.228061
# CRBI       0.583821
# CWalks    -0.690601
# PutOuts    0.292694
# Assists    0.304372
# Errors    -2.450795
# dtype: float64

# %% [markdown]
# From above results we know that the optimal value of the regularization penality is <b>0.0636</b>. There are <b>12</b> predictors are left in that model.

# %% [markdown]
# ### 1.2
# Repeat with Ridge Regression. Visualize coeffecient trajectories. Use cross-validation to find the optimal vaule of the regularization penalty.

# %%
alphas = np.logspace(-3,3,1000)
coefs_ridge = []
for a in alphas:
    ridge = Ridge(alpha= a, max_iter = 1e4, normalize = True)
    ridge.fit(x,y)
    coefs_ridge.append(ridge.coef_)
    
plt.figure(num=None, figsize=(16, 9), dpi=80, facecolor='w', edgecolor='k')    
ax = plt.gca()
ax.plot(alphas, coefs_ridge)
ax.set_xscale('log')
ax.legend(x.columns,loc = 4)
plt.xlabel('lambda')
plt.ylabel('coefficient')
plt.title('Ridge coefficient trajectories')
plt.show()

# %%
ridgecv = RidgeCV(alphas = alphas, cv = 10, normalize = True)
ridgecv.fit(x,y)
ridge.set_params(alpha = ridgecv.alpha_)
ridgecv.alpha_
# Out:
# 0.9794696670695395

# %%
ridge.fit(x,y)
pd.Series(ridge.coef_, index=x.columns)
# Out:
# AtBat      0.092677
# Hits       0.779048
# HmRun      0.717110
# Runs       1.039375
# RBI        0.897415
# Walks      1.540042
# Years      1.992184
# CAtBat     0.011254
# CHits      0.053108
# CHmRun     0.371456
# CRuns      0.106962
# CRBI       0.110625
# CWalks     0.066541
# PutOuts    0.150051
# Assists    0.025306
# Errors    -1.017433
# dtype: float64

# %% [markdown]
# From above results, the optimal vaule of the regularization penalty is <b>0.98</b>

# %% [markdown]
# ### Problem 2
# #### Short Answer. Explain in your own words the bias-variance tradeoff.

# %% [markdown]
# The bias-variance tradeoff is an common but critical issue when building predict models. Bias-variance tradeoff is used to describe the relationship between model accuracy and robustness. If a very flexible model is built, that is the complexity of the model is high, then the model will have low bias and high accuracy. But because that kind of model fit on training data too close, it tend to have high variance. So the model's performance will significantly drop when fit on new data. That is overfitting problem. Therefore, it is important to find some balance point to make the model have relatively low bias and also relativly low variance.

# %% [markdown]
# #### What role does regularization play in this tradeoff?

# %% [markdown]
# Regularization is a way to deal with overfitting problem. It reduces the variance of the model by using penalty parameter to limit the magnitude of coefficients.

# %% [markdown]
# #### Make reference to your findings in number (1) to describe models of high/low bias and variance.
